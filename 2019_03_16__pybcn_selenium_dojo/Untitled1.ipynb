# %%
import visual_testing_tools as vtt

# %%
driver = vtt.get_driver('Chrome', 360, 640)
driver.get("https://www.tiendeo.us/new-york-city-NY/cvs-pharmacy")
vtt.get_full_page_screenshot_with_fixed_header(driver)
# Out:
# Checking for win32 chromedriver:2.46 in cache
# Driver found in C:\Users\Orwell\.wdm\chromedriver\2.46\win32/chromedriver.exe
# Total: (461, 4407), Viewport: (461,509), PixelRatio: 1.5
# <PIL.Image.Image image mode=RGB size=717x6616 at 0x596F850>

# %%
driver = vtt.get_driver('Chrome', 1200, 600)

driver.get("https://www.tiendeo.us/new-york-city-NY/cvs-pharmacy")

vtt.get_full_page_screenshot_with_fixed_header(driver)

# %%
a = 1

# %%
print (a + 1)
# Out:
# 2
